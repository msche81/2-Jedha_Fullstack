# %%
import requests

response_btc = requests.get("https://api.coinranking.com/v2/coins")
response_btc.json()
# Out:
# {'status': 'success',
#  'data': {'stats': {'total': 47712,
#    'totalCoins': 47712,
#    'totalMarkets': 47715,
#    'totalExchanges': 182,
#    'totalMarketCap': '998',
#    'total24hVolume': '211946275044'},
#   'coins': [{'uuid': 'Qwsogvtv82FCd',
#     'symbol': 'BTC',
#     'name': 'Bitcoin',
#     'color': '#f7931A',
#     'iconUrl': 'https://cdn.coinranking.com/bOabBYkcX/bitcoin_btc.svg',
#     'marketCap': '2031359643769',
#     'price': '102526.0884853585',
#     'listedAt': 1330214400,
#     'tier': 1,
#     'change': '-5.08',
#     'rank': 1,
#     'sparkline': ['108301.82101401652',
#      '108304.71433312437',
#      '108214.46527899276',
#      '107090.54907447954',
#      '107397.02143277295',
#      '107780.73048093758',
#      '106778.41602359278',
#      '105609.8350451404',
#      '104092.94196641096',
#      '103746.26076208315',
#      '103493.1540838844',
#      '103906.87971206698',
#      '103629.87494700137',
#      '103047.0951832259',
# ...

# %%
response_btc.json()["data"]["stats"]["totalCoins"]
# Out:
# 47712
