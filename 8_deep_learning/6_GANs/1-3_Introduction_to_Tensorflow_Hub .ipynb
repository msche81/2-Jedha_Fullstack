# %% [markdown]
# Tensorflow Hub is a service provided with tensorflow where researchers and more broadly data scientists can upload and share the models that they train! Which means it's a great place to look for models you may use for transfer learning!
#
# All the models are listed here. They are classified by application, which makes the interface very easy to navigate.

# %% [markdown]
# # How do I use Tensorflow Hub in practice?
# Tensorflow hub is very easy to use, all you have to do is install the tensorflow hub dependency as follows and you are good to go!

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %% [markdown]
# Once you have done that, most models have a usage tutorial included with their documentation, check for example this page.

# %%
inception_v3 = "https://tfhub.dev/google/imagenet/inception_v3/classification/5"

# %%
IMAGE_SHAPE = (224, 224)

classifier = tf.keras.Sequential([
    hub.KerasLayer(inception_v3, input_shape=IMAGE_SHAPE+(3,))
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-040c7caddf8d> in <cell line: 3>()
#       1 IMAGE_SHAPE = (224, 224)
#       2
# ----> 3 classifier = tf.keras.Sequential([
#       4     hub.KerasLayer(inception_v3, input_shape=IMAGE_SHAPE+(3,))
#       5 ])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      72         if layers:
#      73             for layer in layers:
# ---> 74                 self.add(layer, rebuild=False)
#      75             self._maybe_rebuild()
#      76
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#      94                 layer = origin_layer
#      95         if not isinstance(layer, Layer):
# ---> 96             raise ValueError(
#      97                 "Only instances of `keras.Layer` can be "
#      98                 f"added to a Sequential model. Received: {layer} "
#
# ValueError: Only instances of `keras.Layer` can be added to a Sequential model. Received: <tensorflow_hub.keras_layer.KerasLayer object at 0x7c594dcf64d0> (of type <class 'tensorflow_hub.keras_layer.KerasLayer'>)
