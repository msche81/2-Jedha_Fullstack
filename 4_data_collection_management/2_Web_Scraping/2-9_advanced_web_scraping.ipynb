# %%
import os
import logging
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
# !python src/scrapy3.py
# Out:
# 2024-08-28 13:59:58 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-08-28 13:59:58 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 13:59:58 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 13:59:58 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 13:59:58 [scrapy.extensions.telnet] INFO: Telnet Password: e50abaaa1f8b5469
# 2024-08-28 13:59:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-08-28 13:59:58 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2024-08-28 13:59:58 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 13:59:58 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 13:59:58 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 13:59:58 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 13:59:58 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 13:59:58 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:00:02 [root] INFO: No next page. Terminating crawling process.
# 2024-08-28 14:00:02 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-28 14:00:02 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: src/3_quotesmultiplepages.json
# 2024-08-28 14:00:02 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2436,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 109760,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 10,
#  'elapsed_time_seconds': 3.495353,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 28, 12, 0, 2, 465139, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 100,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 1,
#  'memusage/max': 66535424,
#  'memusage/startup': 66535424,
#  'request_depth_max': 9,
#  'response_received_count': 10,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2024, 8, 28, 11, 59, 58, 969786, tzinfo=datetime.timezone.utc)}
# 2024-08-28 14:00:02 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !python src/scrapy4.py
# Out:
# 2024-08-28 14:00:17 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-08-28 14:00:17 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 14:00:17 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 14:00:17 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 14:00:17 [scrapy.extensions.telnet] INFO: Telnet Password: da493aeb9629d39b
# 2024-08-28 14:00:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-08-28 14:00:17 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2024-08-28 14:00:17 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 14:00:17 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 14:00:17 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 14:00:17 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 14:00:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:00:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:00:20 [root] INFO: No next page. Terminating crawling process.
# 2024-08-28 14:00:20 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-28 14:00:20 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: src/4_quotesauthentication.json
# 2024-08-28 14:00:20 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 4888,
#  'downloader/request_count': 12,
#  'downloader/request_method_count/GET': 11,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 121068,
#  'downloader/response_count': 12,
#  'downloader/response_status_count/200': 11,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 3.163605,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 28, 12, 0, 20, 779448, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 100,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 1,
#  'memusage/max': 67108864,
#  'memusage/startup': 67108864,
#  'request_depth_max': 10,
#  'response_received_count': 11,
#  'scheduler/dequeued': 12,
#  'scheduler/dequeued/memory': 12,
#  'scheduler/enqueued': 12,
#  'scheduler/enqueued/memory': 12,
#  'start_time': datetime.datetime(2024, 8, 28, 12, 0, 17, 615843, tzinfo=datetime.timezone.utc)}
# 2024-08-28 14:00:20 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# !python src/scrapy5.py
# Out:
# 2024-08-28 14:00:21 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-08-28 14:00:21 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 14:00:21 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 14:00:21 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 14:00:21 [scrapy.extensions.telnet] INFO: Telnet Password: 5dc16ec593b6c41d
# 2024-08-28 14:00:21 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-08-28 14:00:21 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20, 'USER_AGENT': 'Chrome/97.0'}
# 2024-08-28 14:00:21 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 14:00:21 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 14:00:21 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 14:00:21 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 14:00:21 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:00:21 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:00:22 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-28 14:00:22 [scrapy.extensions.feedexport] INFO: Stored json feed (20 items) in: src/5_quotesmultiplespiders.json
# 2024-08-28 14:00:22 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 406,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 25027,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.613558,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 28, 12, 0, 22, 370009, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 20,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'memusage/max': 67190784,
#  'memusage/startup': 67190784,
#  'response_received_count': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2024, 8, 28, 12, 0, 21, 756451, tzinfo=datetime.timezone.utc)}
# 2024-08-28 14:00:22 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
os.chdir("src")
os.getcwd()
# !scrapy startproject tutorial
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.chdir("src")
#       2 os.getcwd()
#       3 get_ipython().system('scrapy startproject tutorial')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'src'

# %%
os.chdir("tutorial")
os.getcwd()
# Out:
# '/Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src/tutorial'

# %%
# !scrapy crawl autothrottle -O results/7_quotesautothrottle.json
# Out:
# 2024-08-28 14:06:24 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: tutorial)
# 2024-08-28 14:06:24 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 14:06:24 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 14:06:24 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 14:06:24 [scrapy.extensions.telnet] INFO: Telnet Password: 3ba08bdcd4577dc4
# 2024-08-28 14:06:24 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2024-08-28 14:06:24 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': True,
#  'BOT_NAME': 'tutorial',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'tutorial.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['tutorial.spiders']}
# 2024-08-28 14:06:24 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 14:06:24 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 14:06:24 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 14:06:24 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 14:06:24 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:06:24 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:06:42 [root] INFO: No next page. Terminating crawling process.
# 2024-08-28 14:06:42 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-28 14:06:42 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: results/7_quotesautothrottle.json
# 2024-08-28 14:06:42 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2906,
#  'downloader/request_count': 11,
#  'downloader/request_method_count/GET': 11,
#  'downloader/response_bytes': 110091,
#  'downloader/response_count': 11,
#  'downloader/response_status_count/200': 10,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 17.697047,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 28, 12, 6, 42, 28570, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 100,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 1,
#  'memusage/max': 69271552,
#  'memusage/startup': 69271552,
#  'request_depth_max': 9,
#  'response_received_count': 11,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2024, 8, 28, 12, 6, 24, 331523, tzinfo=datetime.timezone.utc)}
# 2024-08-28 14:06:42 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
os.chdir("..")
os.getcwd()
# Out:
# '/Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src'

# %%
# !scrapy startproject rotate_user_agent
# Out:
# Error: scrapy.cfg already exists in /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src/rotate_user_agent

# %%
os.chdir("rotate_user_agent")
os.getcwd()
# Out:
# '/Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src/rotate_user_agent'

# %%
# !scrapy crawl rotate_user_agent -O results/rotate_user_agent.json
# Out:
# 2024-08-28 14:10:42 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: rotate_user_agent)
# 2024-08-28 14:10:42 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 14:10:42 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 14:10:42 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 14:10:42 [scrapy.extensions.telnet] INFO: Telnet Password: 05105bd78770ba66
# 2024-08-28 14:10:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-08-28 14:10:42 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'rotate_user_agent',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'rotate_user_agent.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['rotate_user_agent.spiders']}
# 2024-08-28 14:10:42 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Android
# 2024-08-28 14:10:42 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:42 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:42 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Sony BDV13, Brand: Sony, Model: BDV13
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Nintendo DSi, Brand: Nintendo, Model: DSi
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Other
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: LYF F90M, Brand: LYF, Model: F90M
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Sony BDV14, Brand: Sony, Model: BDV14
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: LG Web0S SmartTV, Brand: LG, Model: Web0S SmartTV
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Sony BDV11, Brand: Sony, Model: BDV11
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Nintendo DSi, Brand: Nintendo, Model: DSi
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: LYF LF-2403N, Brand: LYF, Model: LF-2403N
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: LYF F90M, Brand: LYF, Model: F90M
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Applebot
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Applebot
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Other
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Other
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: SMTBot
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: WebKit Nightly
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: PhantomJS
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Robot
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedDeviceType] Family: Other, Brand: None, Model: None
# 2024-08-28 14:10:43 [scrapy_user_agents.user_agent_picker] WARNING: [UnsupportedBrowserType] Family: Zune
# 2024-08-28 14:10:43 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy_user_agents.middlewares.RandomUserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 14:10:43 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 14:10:43 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 14:10:43 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 14:10:43 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:10:43 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:10:47 [root] INFO: No next page. Terminating crawling process.
# 2024-08-28 14:10:47 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-08-28 14:10:47 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: results/rotate_user_agent.json
# 2024-08-28 14:10:47 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 3743,
#  'downloader/request_count': 11,
#  'downloader/request_method_count/GET': 11,
#  'downloader/response_bytes': 110091,
#  'downloader/response_count': 11,
#  'downloader/response_status_count/200': 10,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 3.16107,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 8, 28, 12, 10, 47, 131450, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 100,
#  'log_count/INFO': 12,
#  'log_count/WARNING': 46,
#  'memusage/max': 70434816,
#  'memusage/startup': 70434816,
#  'request_depth_max': 9,
#  'response_received_count': 11,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2024, 8, 28, 12, 10, 43, 970380, tzinfo=datetime.timezone.utc)}
# 2024-08-28 14:10:47 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
ROTATING_PROXY_LIST = [
    'Proxy_IP:port',
    'Proxy_IP:port',
    # ...
]

# %%
ROTATING_PROXY_LIST_PATH = 'listofproxies.txt'

# %%
os.chdir("..")
os.getcwd()
# Out:
# '/Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src'

# %%
import pandas as pd

proxy = pd.read_csv("Free_Proxy_List.csv")
proxy
# Out:
#                  ip   port anonymityLevel       asn country  \
# 0     38.91.106.204  40103          elite       NaN      US
# 1    147.135.255.62   8242          elite   AS16276      FR
# 2   178.128.178.169   3128    transparent       NaN      US
# 3    43.249.224.170     84    transparent   AS18229      IN
# 4     62.109.31.192  20000          elite   AS29182      RU
# 5   173.244.200.156  49086          elite   AS32780      US
# 6     191.243.217.1  53281          elite       NaN      BR
# 7      195.29.77.19   8080    transparent       NaN      HR
# 8     88.157.181.42   8080    transparent       NaN      PT
# 9   188.132.241.165  56109          elite   AS42910      TR
# 10  191.243.218.249  53281          elite       NaN      BR
# 11  143.198.237.236   9050          elite   AS14061      US
# 12     138.68.42.77   3128    transparent       NaN      US
# 13    66.170.183.90   9090          elite   AS22113      CA
# 14     142.93.24.89   3128    transparent       NaN      US
# 15    88.250.55.132   8080          elite   AS47331      TR
# 16  136.243.174.243   1080          elite       NaN      DE
# 17   144.202.113.90   8080          elite   AS20473      US
# 18     142.93.31.20   3128    transparent       NaN      US
# 19  209.140.194.152   3128    transparent  AS394289      US
# 20    64.227.62.123     80          elite   AS14061      US
# 21   103.28.160.134   8080    transparent   AS17907      AU
# 22   50.233.228.147   8080      anonymous       NaN      US
# 23  157.230.255.230   8118          elite       NaN      SG
# 24  143.110.151.242   3128          elite       NaN      US
# 25  188.166.206.183   8118          elite       NaN      SG
# 26     5.188.182.54   3128          elite       NaN      RU
# 27  173.244.200.154  36636          elite   AS32780      US
# 28    51.159.24.172   3163          elite       NaN      FR
# 29   184.180.90.226   8080    transparent       NaN      US
# 30     165.22.59.84   8080    transparent       NaN      SG
# 31   167.99.163.146   3128    transparent       NaN      US
# 32   75.111.123.167   1888          elite   AS19108      US
# 33    138.36.151.11   8090    transparent       NaN      AR
# 34      51.81.6.160  60509          elite       NaN      US
# 35  197.211.238.220  36851          elite   AS30969      ZW
# 36     128.199.4.92   3129    transparent       NaN      SG
# 37  167.172.203.244   8118          elite   AS14061      US
# 38    68.183.129.76   3129    transparent       NaN      US
# 39   137.74.196.132   3128    transparent       NaN      FR
# 40     177.75.96.74   3128    transparent  AS265889      BR
# 41    142.93.16.163   3128    transparent       NaN      US
# 42    67.213.212.13  32980          elite       NaN      US
# 43  222.165.205.154   5678          elite       NaN      ID
# 44   193.193.240.37  48785          elite       NaN      KZ
# 45  188.132.241.162  56109          elite       NaN      TR
# 46   43.249.224.170     83    transparent   AS18229      IN
# 47   147.135.255.62   8139          elite   AS16276      FR
# 48   147.135.255.62   8122          elite   AS16276      FR
# 49  173.244.200.154  44302          elite   AS32780      US
#
#                                isp  latency  \
# 0                              NaN     73.0
# 1                          OVH SAS    144.0
# 2                              NaN      2.0
# 3       Equinox Consulting PVT LTD    221.0
# 4                   Cjsc the First    181.0
# 5           Hosting Services, Inc.     77.0
# 6                              NaN    145.0
# 7                              NaN    177.0
# 8                              NaN    177.0
# 9                    Sadecehosting      NaN
# 10                             NaN    146.0
# 11               DigitalOcean, LLC      3.0
# 12                             NaN      2.0
# 13             Belair Technologies     86.0
# 14                             NaN      2.0
# 15                     TurkTelecom    199.0
# 16                             NaN    161.0
# 17                          Choopa      8.0
# 18                             NaN      3.0
# 19                    Hope College     66.0
# 20               DigitalOcean, LLC      2.0
# 21                         RA-WIFI    172.0
# 22                             NaN     28.0
# 23                             NaN    192.0
# 24                             NaN      3.0
# 25                             NaN    184.0
# 26                             NaN    144.0
# 27          Hosting Services, Inc.     74.0
# 28                             NaN    142.0
# 29                             NaN     58.0
# 30                             NaN    174.0
# 31                             NaN      2.0
# 32       Suddenlink Communications      NaN
# 33                             NaN    209.0
# 34                             NaN     66.0
# 35  Zimbabwe Online (Private) Ltd.    335.0
# 36                             NaN      2.0
# 37               DigitalOcean, LLC      2.0
# 38                             NaN     76.0
# 39                             NaN    154.0
# 40   Optinet TelecomunicaÔÔes Ltda    210.0
# 41                             NaN      2.0
# 42                             NaN     77.0
# 43                             NaN    208.0
# 44                             NaN    240.0
# 45                             NaN      NaN
# 46      Equinox Consulting PVT LTD    236.0
# 47                         OVH SAS    142.0
# 48                         OVH SAS    142.0
# 49          Hosting Services, Inc.     76.0
#
#                                                   org protocols  responseTime  \
# 0                                                 NaN    socks5           NaN
# 1                                                 OVH      http          61.0
# 2                                                 NaN     https           NaN
# 3                                  Pioneer Elabs Ltd.      http          46.0
# 4                                            TheFirst    socks5          35.0
# 5                              Hosting Services, Inc.    socks5          51.0
# 6                                                 NaN     https           NaN
# 7                                                 NaN      http           NaN
# 8                                                 NaN     https           NaN
# 9   Equinix Turkey Internet Hizmetleri Anonim Sirketi    socks4          38.0
# 10                                                NaN     https           NaN
# 11                                  DigitalOcean, LLC    socks5          35.0
# 12                                                NaN     https           NaN
# 13                                Belair Technologies      http          35.0
# 14                                                NaN     https           NaN
# 15                          Turk Telekomunikasyon A.S    socks4          35.0
# 16                                                NaN    socks4           NaN
# 17                                Vultr Holdings, LLC      http          46.0
# 18                                                NaN     https           NaN
# 19                                       Hope College     https          39.0
# 20                                  DigitalOcean, LLC      http          35.0
# 21                                            RA-WIFI     https          52.0
# 22                                                NaN     https           NaN
# 23                                                NaN      http           NaN
# 24                                                NaN     https           NaN
# 25                                                NaN      http           NaN
# 26                                                NaN     https           NaN
# 27                             Hosting Services, Inc.    socks4          69.0
# 28                                                NaN     https           NaN
# 29                                                NaN     https           NaN
# 30                                                NaN      http           NaN
# 31                                                NaN      http           NaN
# 32                          Suddenlink Communications    socks5          37.0
# 33                                                NaN      http           NaN
# 34                                                NaN    socks4           NaN
# 35                               ZOL Cust Assignments    socks4          34.0
# 36                                                NaN     https           NaN
# 37                                  DigitalOcean, LLC      http          38.0
# 38                                                NaN     https           NaN
# 39                                                NaN      http           NaN
# 40                      Optinet Telecomunicações Ltda     https          35.0
# 41                                                NaN      http           NaN
# 42                                                NaN    socks5           NaN
# 43                                                NaN    socks4           NaN
# 44                                                NaN    socks4           NaN
# 45                                                NaN    socks5           NaN
# 46                                 Pioneer Elabs Ltd.      http          46.0
# 47                                                OVH     https          61.0
# 48                                                OVH      http          37.0
# 49                             Hosting Services, Inc.    socks4          69.0
#
#       speed                updated_at  upTime  upTimeSuccessCount  \
# 0       1.0  2022-01-14T16:01:23.480Z     100                4616
# 1     286.0  2022-01-14T16:01:21.197Z     100                  54
# 2       NaN  2022-01-14T16:01:21.307Z     100                4811
# 3       NaN  2022-01-14T16:01:20.509Z     100                  73
# 4       1.0  2022-01-14T16:01:17.958Z     100                  54
# 5       1.0  2022-01-14T16:01:15.676Z     100                  45
# 6       NaN  2022-01-14T16:01:13.476Z     100                4771
# 7       NaN  2022-01-14T16:01:11.084Z     100                4737
# 8     355.0  2022-01-14T16:01:08.624Z     100                4785
# 9       1.0  2022-01-14T16:01:06.170Z      98                3925
# 10      NaN  2022-01-14T16:01:02.040Z     100                4752
# 11      1.0  2022-01-14T16:00:59.644Z      54                2504
# 12      NaN  2022-01-14T16:00:59.177Z     100                4787
# 13      NaN  2022-01-14T16:00:59.537Z      99                4746
# 14      NaN  2022-01-14T16:00:59.071Z     100                4796
# 15      1.0  2022-01-14T16:00:58.307Z     100                4789
# 16      1.0  2022-01-14T16:00:58.863Z     100                4777
# 17     18.0  2022-01-14T16:00:58.439Z     100                4803
# 18      NaN  2022-01-14T16:00:58.966Z     100                4801
# 19      NaN  2022-01-14T16:00:57.699Z     100                4798
# 20      NaN  2022-01-14T16:00:57.804Z     100                4805
# 21      NaN  2022-01-14T16:00:55.438Z     100                4789
# 22     58.0  2022-01-14T16:00:52.994Z     100                4771
# 23      NaN  2022-01-14T16:00:50.034Z     100                4791
# 24      NaN  2022-01-14T16:00:50.138Z     100                4785
# 25      NaN  2022-01-14T16:00:50.806Z     100                4778
# 26      NaN  2022-01-14T16:00:49.395Z     100                4795
# 27      1.0  2022-01-14T16:00:44.736Z     100                  45
# 28      NaN  2022-01-14T16:00:42.544Z     100                 973
# 29    167.0  2022-01-14T16:00:41.873Z     100                4799
# 30    362.0  2022-01-14T16:00:39.549Z     100                4806
# 31      NaN  2022-01-14T16:00:36.910Z     100                4795
# 32      1.0  2022-01-14T16:00:36.792Z      12                 554
# 33      NaN  2022-01-14T16:00:32.692Z     100                4737
# 34      1.0  2022-01-14T16:00:30.155Z     100                4631
# 35      1.0  2022-01-14T16:00:27.440Z      96                4134
# 36      NaN  2022-01-14T16:00:27.547Z     100                4780
# 37      NaN  2022-01-14T16:00:27.650Z     100                4780
# 38      NaN  2022-01-14T16:00:27.988Z     100                4774
# 39      NaN  2022-01-14T16:00:25.004Z     100                4799
# 40      NaN  2022-01-14T16:00:22.584Z     100                4792
# 41      NaN  2022-01-14T16:00:20.066Z     100                4744
# 42      1.0  2022-01-14T16:00:19.957Z     100                4628
# 43  30004.0  2022-01-14T16:00:30.149Z     100                   1
# 44  30003.0  2022-01-14T16:00:30.127Z     100                   1
# 45      1.0  2022-01-14T16:00:48.846Z      98                3951
# 46      NaN  2021-06-29T13:03:20.582Z     100                  66
# 47    296.0  2021-06-29T13:02:00.860Z     100                  38
# 48    299.0  2021-06-29T13:01:55.317Z     100                  47
# 49    163.0  2021-06-29T13:01:16.017Z     100                  43
#
#     upTimeTryCount
# 0             4622
# 1               54
# 2             4811
# 3               73
# 4               54
# 5               45
# 6             4776
# 7             4740
# 8             4785
# 9             4010
# 10            4758
# 11            4654
# 12            4787
# 13            4782
# 14            4796
# 15            4806
# 16            4781
# 17            4804
# 18            4801
# 19            4809
# 20            4806
# 21            4790
# 22            4772
# 23            4795
# 24            4786
# 25            4783
# 26            4800
# 27              45
# 28             974
# 29            4801
# 30            4808
# 31            4795
# 32            4795
# 33            4744
# 34            4631
# 35            4296
# 36            4781
# 37            4780
# 38            4776
# 39            4800
# 40            4800
# 41            4744
# 42            4634
# 43               1
# 44               1
# 45            4034
# 46              66
# 47              38
# 48              47
# 49              43

# %%
proxy_list = [f"{row[0]}:{row[1]}" for row in zip(proxy["ip"],proxy["port"])]
proxy_list[:3]
# Out:
# ['38.91.106.204:40103', '147.135.255.62:8242', '178.128.178.169:3128']

# %%
textfile = open("proxy.txt", "w")
for element in proxy_list:
    textfile.write(element + "\n")
textfile.close()

# %%
# !scrapy startproject rotate_proxy
# Out:
# Error: scrapy.cfg already exists in /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/4_data_collection_management/2_Web_Scraping/src/rotate_proxy

# %%
os.chdir("rotate_proxy")

# %%
# !scrapy crawl rotate_proxy -O results/9_rotate_proxy.json
# Out:
# 2024-08-28 14:17:26 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: rotate_proxy)
# 2024-08-28 14:17:26 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.4 (main, Jun  6 2024, 18:26:44) [Clang 15.0.0 (clang-1500.3.9.4)], pyOpenSSL 24.2.1 (OpenSSL 3.3.1 4 Jun 2024), cryptography 43.0.0, Platform macOS-14.6.1-arm64-arm-64bit
# 2024-08-28 14:17:26 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-08-28 14:17:26 [py.warnings] WARNING: /Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-08-28 14:17:26 [scrapy.extensions.telnet] INFO: Telnet Password: bb7d4b8a860773a4
# 2024-08-28 14:17:26 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-08-28 14:17:26 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'rotate_proxy',
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'rotate_proxy.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['rotate_proxy.spiders']}
# 2024-08-28 14:17:26 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'rotating_proxies.middlewares.RotatingProxyMiddleware',
#  'rotating_proxies.middlewares.BanDetectionMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-08-28 14:17:26 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-08-28 14:17:26 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-08-28 14:17:26 [scrapy.core.engine] INFO: Spider opened
# 2024-08-28 14:17:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:17:26 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-08-28 14:17:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 0, unchecked: 50, reanimated: 0, mean backoff time: 0s)
# 2024-08-28 14:17:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 49, reanimated: 0, mean backoff time: 154s)
# 2024-08-28 14:18:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:18:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 49, reanimated: 0, mean backoff time: 154s)
# 2024-08-28 14:18:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 48, reanimated: 0, mean backoff time: 113s)
# 2024-08-28 14:19:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:19:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 48, reanimated: 0, mean backoff time: 113s)
# 2024-08-28 14:19:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 48, reanimated: 0, mean backoff time: 113s)
# 2024-08-28 14:20:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:20:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 0, unchecked: 47, reanimated: 3, mean backoff time: 0s)
# 2024-08-28 14:20:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 0, unchecked: 47, reanimated: 3, mean backoff time: 0s)
# 2024-08-28 14:21:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:21:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 46, reanimated: 3, mean backoff time: 117s)
# 2024-08-28 14:21:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 46, reanimated: 3, mean backoff time: 117s)
# 2024-08-28 14:22:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:22:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 46, reanimated: 3, mean backoff time: 117s)
# 2024-08-28 14:22:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 45, reanimated: 3, mean backoff time: 134s)
# 2024-08-28 14:23:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:23:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 1, unchecked: 45, reanimated: 4, mean backoff time: 151s)
# 2024-08-28 14:23:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 44, reanimated: 4, mean backoff time: 111s)
# 2024-08-28 14:24:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:24:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 44, reanimated: 4, mean backoff time: 111s)
# 2024-08-28 14:24:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 44, reanimated: 4, mean backoff time: 111s)
# 2024-08-28 14:24:57 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET http://quotes.toscrape.com/robots.txt> (failed 3 times): Connection was refused by other side: 61: Connection refused.
# 2024-08-28 14:24:57 [scrapy.downloadermiddlewares.robotstxt] ERROR: Error downloading <GET http://quotes.toscrape.com/robots.txt>: Connection was refused by other side: 61: Connection refused.
# Traceback (most recent call last):
#   File "/Users/marie-sophiechenevier/Library/CloudStorage/Dropbox/2024-DataScience/GitHub/2-Jedha_Fullstack/.venv/lib/python3.12/site-packages/scrapy/core/downloader/middleware.py", line 54, in process_request
#     return (yield download_func(request=request, spider=spider))
# twisted.internet.error.ConnectionRefusedError: Connection was refused by other side: 61: Connection refused.
# 2024-08-28 14:25:26 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-08-28 14:25:26 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 42, reanimated: 6, mean backoff time: 139s)
# 2024-08-28 14:25:56 [rotating_proxies.middlewares] INFO: Proxies(good: 0, dead: 2, unchecked: 42, reanimated: 6, mean backoff time: 139s)
# ^C
# 2024-08-28 14:26:10 [scrapy.crawler] INFO: Received SIGINT, shutting down gracefully. Send again to force
# 2024-08-28 14:26:10 [scrapy.core.engine] INFO: Closing spider (shutdown)
