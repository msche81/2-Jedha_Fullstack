# %%
import numpy as np
import math

# %%
# Example with numpy: pow and sqrt
print("4 squared: ", math.pow(4, 2))
print("2 power 5: ", math.pow(2, 5)) #“2 à la puissance 5” signifie que le nombre 2 est multiplié par lui-même 5 fois.
print("Square root of 25: ", np.sqrt(25)) # sqrt is not in the math module !
print("Cube root of 64: ", np.cbrt(64)) # neither is cbrt ! La racine cubique de 64 signifie trouver un nombre qui, lorsqu’il est multiplié par lui-même trois fois, donne 64
# Out:
# 4 squared:  16.0
# 2 power 5:  32.0
# Square root of 25:  5.0
# Cube root of 64:  4.0

# %%
# Exponential and logarithm
# Example with numpy
print("Exponential of 1: ", np.exp(1))
print("Exponential of 0: ", np.exp(0))
print("Natural logarithm of 10: ", np.log(10)) # "log" refers to the natural logarithm
print("Base 10 logarithm of 10: ", np.log10(10)) # "log10" refers to the logarithm of base 10
# Out:
# Exponential of 1:  2.718281828459045
# Exponential of 0:  1.0
# Natural logarithm of 10:  2.302585092994046
# Base 10 logarithm of 10:  1.0

# %%
# trigonometrics functions
# Examples with numpy
print("Cosinus of 0: ", np.cos(0))
print("Cosinus of pi: ", np.cos(np.pi))
print("Cosinus of pi/2: ", np.cos(np.pi/2).round(2))
print()
print("Sinus of 0: ", np.sin(0))
print("Sinus of pi: ", np.sin(np.pi).round(2))
print("Sinus of pi/2: ", np.sin(np.pi/2))
print()
print("Tan of 0: ", np.tan(0))
print("Tan of pi: ", np.tan(np.pi).round(2))
print("Tan of pi/2: ", np.tan(np.pi/2)) # this will diverge !
print()
# Out:
# Cosinus of 0:  1.0
# Cosinus of pi:  -1.0
# Cosinus of pi/2:  0.0
#
# Sinus of 0:  0.0
# Sinus of pi:  0.0
# Sinus of pi/2:  1.0
#
# Tan of 0:  0.0
# Tan of pi:  -0.0
# Tan of pi/2:  1.633123935319537e+16

# %%
# random numbers
print("Sample of 30 random values drawn from a discrete uniform distribution on [0, 10]: ")
print(np.random.randint(0, 10, 30))
print()
print("Sample of 20 random values drawn from a discrete uniform distribution on [-2, 2]: ")
print(np.random.randint(-2, 2, 20))
print()
# Out:
# Sample of 30 random values drawn from a discrete uniform distribution on [0, 10]:
# [4 5 8 9 5 6 2 6 6 2 1 4 2 0 8 4 5 6 9 1 8 6 9 7 9 8 6 7 0 1]
#
# Sample of 20 random values drawn from a discrete uniform distribution on [-2, 2]:
# [ 0 -1 -2  1 -2  1 -2  0  0 -2 -1  1  0 -2  1  1  0  1 -2  0]

# %%
# Distribution Uniforme Discrète
# Générer 10 nombres entiers aléatoires entre 1 et 6 (inclus)
result = np.random.randint(1, 7, size=10)
print(result)
# Out:
# [5 4 4 5 1 4 3 6 2 5]

# %%
# Distribution Binomiale
# Générer des échantillons binomiaux
n = 10  # Nombre d'essais
p = 0.5  # Probabilité de succès
size = 10  # Nombre d'échantillons à générer

result = np.random.binomial(n, p, size)
print(result)
# Out:
# [2 7 5 6 6 4 2 4 5 5]

# %%
# Distribution de Poisson
# Générer des échantillons de Poisson
lambda_param = 3  # Taux moyen d'événements
size = 10  # Nombre d'échantillons à générer

result = np.random.poisson(lambda_param, size)
print(result)
# Out:
# [2 5 5 4 0 3 4 6 4 2]

# %%
# Probability densities for continuous variables
# Distribution Normale (Gaussienne)
import matplotlib.pyplot as plt

# Générer des échantillons de la distribution normale
mean = 0  # Moyenne
std_dev = 1  # Écart type
samples = np.random.normal(mean, std_dev, 1000)

# Tracer l'histogramme des échantillons
plt.hist(samples, bins=30, density=True)
plt.title('Distribution Normale')
plt.xlabel('Valeur')
plt.ylabel('Densité de Probabilité')
plt.show()

# %%
# Distribution Uniforme Continue
# Générer des échantillons de la distribution uniforme
low = 0  # Borne inférieure
high = 1  # Borne supérieure
samples = np.random.uniform(low, high, 1000)

# Tracer l'histogramme des échantillons
plt.hist(samples, bins=30, density=True)
plt.title('Distribution Uniforme Continue')
plt.xlabel('Valeur')
plt.ylabel('Densité de Probabilité')
plt.show()

# %%
# Distribution Exponentielle
# Générer des échantillons de la distribution exponentielle
lambda_param = 1  # Taux
samples = np.random.exponential(1/lambda_param, 1000)

# Tracer l'histogramme des échantillons
plt.hist(samples, bins=30, density=True)
plt.title('Distribution Exponentielle')
plt.xlabel('Valeur')
plt.ylabel('Densité de Probabilité')
plt.show()

# %%
# Distribution Uniforme Continue
print("Sample of 30 random values drawn from a uniform distribution on [a,b] = [0, 10]:")
print(np.random.uniform(0, 10, 30))
print()
print("Sample of 20 random values drawn from a uniform distribution on [a,b] = [-5, 5]:")
print(np.random.uniform(-5, 5, 20))
# Out:
# Sample of 30 random values drawn from a uniform distribution on [a,b] = [0, 10]:
# [4.35252629 2.47576521 7.74514907 5.5172496  7.7175466  4.74012043
#  2.78498655 2.08433825 8.87309492 7.43096939 4.93125192 1.98183828
#  5.32893757 8.03401729 1.42116704 7.96759476 9.17651417 2.81351019
#  0.87527789 7.1008099  4.44259174 3.63182446 1.09786847 5.78161986
#  7.94871357 4.20492183 8.23980127 5.96113042 1.97298073 7.27935919]
#
# Sample of 20 random values drawn from a uniform distribution on [a,b] = [-5, 5]:
# [ 4.46132219 -4.77598336  4.33942748  4.74058617 -2.29991669  4.36115104
#  -4.37745132  4.81664714 -3.90486746 -4.15123155  1.89041216 -2.54427104
#  -1.86298122  2.08975624 -4.30774822  4.9381956  -3.8833386  -1.42614548
#  -2.87591029  1.96927383]

# %%
# Distribution Normal Gaussienne
print("Sample of 20 random values drawn from a normal distribution of mean 5 and std 2:")
print(np.random.normal(5, 2, 20))
# Out:
# Sample of 20 random values drawn from a normal distribution of mean 5 and std 2:
# [1.90225508 4.18798905 3.20922197 6.11838707 7.12830208 9.79788342
#  3.73201897 3.53065091 4.93252328 4.57214879 5.95864537 5.62696194
#  4.65005702 2.42361823 6.09395242 3.70588559 4.70309106 5.02497519
#  3.8558152  3.58029454]
